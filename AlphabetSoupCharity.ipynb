# %% [markdown]
# ## Preprocessing

# %%
# !pip install tensorflow
# Out:
# Collecting tensorflow
#   Obtaining dependency information for tensorflow from https://files.pythonhosted.org/packages/20/ba/7560053dbd0b2f5e3654c6d0ad57267558d2d17aec6604a9f6a3fdfb4d5c/tensorflow-2.15.0-cp310-cp310-macosx_10_15_x86_64.whl.metadata
#   Using cached tensorflow-2.15.0-cp310-cp310-macosx_10_15_x86_64.whl.metadata (4.2 kB)
# Requirement already satisfied: absl-py>=1.0.0 in /Users/nancyulloa/anaconda3/envs/dev/lib/python3.10/site-packages (from tensorflow) (2.1.0)
# Requirement already satisfied: astunparse>=1.6.0 in /Users/nancyulloa/anaconda3/envs/dev/lib/python3.10/site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in /Users/nancyulloa/anaconda3/envs/dev/lib/python3.10/site-packages (from tensorflow) (23.5.26)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /Users/nancyulloa/anaconda3/envs/dev/lib/python3.10/site-packages (from tensorflow) (0.5.4)
# Requirement already satisfied: google-pasta>=0.1.1 in /Users/nancyulloa/anaconda3/envs/dev/lib/python3.10/site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in /Users/nancyulloa/anaconda3/envs/dev/lib/python3.10/site-packages (from tensorflow) (3.9.0)
# Requirement already satisfied: libclang>=13.0.0 in /Users/nancyulloa/anaconda3/envs/dev/lib/python3.10/site-packages (from tensorflow) (16.0.6)
# Requirement already satisfied: ml-dtypes~=0.2.0 in /Users/nancyulloa/anaconda3/envs/dev/lib/python3.10/site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: numpy<2.0.0,>=1.23.5 in /Users/nancyulloa/anaconda3/envs/dev/lib/python3.10/site-packages (from tensorflow) (1.26.4)
# Requirement already satisfied: opt-einsum>=2.3.2 in /Users/nancyulloa/anaconda3/envs/dev/lib/python3.10/site-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: packaging in /Users/nancyulloa/anaconda3/envs/dev/lib/python3.10/site-packages (from tensorflow) (23.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /Users/nancyulloa/anaconda3/envs/dev/lib/python3.10/site-packages (from tensorflow) (4.25.3)
# Requirement already satisfied: setuptools in /Users/nancyulloa/anaconda3/envs/dev/lib/python3.10/site-packages (from tensorflow) (68.0.0)
# Requirement already satisfied: six>=1.12.0 in /Users/nancyulloa/anaconda3/envs/dev/lib/python3.10/site-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /Users/nancyulloa/anaconda3/envs/dev/lib/python3.10/site-packages (from tensorflow) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /Users/nancyulloa/anaconda3/envs/dev/lib/python3.10/site-packages (from tensorflow) (4.7.1)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in /Users/nancyulloa/anaconda3/envs/dev/lib/python3.10/site-packages (from tensorflow) (1.14.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /Users/nancyulloa/anaconda3/envs/dev/lib/python3.10/site-packages (from tensorflow) (0.36.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /Users/nancyulloa/anaconda3/envs/dev/lib/python3.10/site-packages (from tensorflow) (1.60.1)
# Requirement already satisfied: tensorboard<2.16,>=2.15 in /Users/nancyulloa/anaconda3/envs/dev/lib/python3.10/site-packages (from tensorflow) (2.15.2)
# Requirement already satisfied: tensorflow-estimator<2.16,>=2.15.0 in /Users/nancyulloa/anaconda3/envs/dev/lib/python3.10/site-packages (from tensorflow) (2.15.0)
# Requirement already satisfied: keras<2.16,>=2.15.0 in /Users/nancyulloa/anaconda3/envs/dev/lib/python3.10/site-packages (from tensorflow) (2.15.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /Users/nancyulloa/anaconda3/envs/dev/lib/python3.10/site-packages (from astunparse>=1.6.0->tensorflow) (0.38.4)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /Users/nancyulloa/anaconda3/envs/dev/lib/python3.10/site-packages (from tensorboard<2.16,>=2.15->tensorflow) (2.28.1)
# Requirement already satisfied: google-auth-oauthlib<2,>=0.5 in /Users/nancyulloa/anaconda3/envs/dev/lib/python3.10/site-packages (from tensorboard<2.16,>=2.15->tensorflow) (1.2.0)
# Requirement already satisfied: markdown>=2.6.8 in /Users/nancyulloa/anaconda3/envs/dev/lib/python3.10/site-packages (from tensorboard<2.16,>=2.15->tensorflow) (3.4.1)
# Requirement already satisfied: requests<3,>=2.21.0 in /Users/nancyulloa/anaconda3/envs/dev/lib/python3.10/site-packages (from tensorboard<2.16,>=2.15->tensorflow) (2.31.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /Users/nancyulloa/anaconda3/envs/dev/lib/python3.10/site-packages (from tensorboard<2.16,>=2.15->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /Users/nancyulloa/anaconda3/envs/dev/lib/python3.10/site-packages (from tensorboard<2.16,>=2.15->tensorflow) (2.2.3)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /Users/nancyulloa/anaconda3/envs/dev/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow) (5.3.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /Users/nancyulloa/anaconda3/envs/dev/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in /Users/nancyulloa/anaconda3/envs/dev/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /Users/nancyulloa/anaconda3/envs/dev/lib/python3.10/site-packages (from google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow) (1.3.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/nancyulloa/anaconda3/envs/dev/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/nancyulloa/anaconda3/envs/dev/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/nancyulloa/anaconda3/envs/dev/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/nancyulloa/anaconda3/envs/dev/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow) (2023.7.22)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /Users/nancyulloa/anaconda3/envs/dev/lib/python3.10/site-packages (from werkzeug>=1.0.1->tensorboard<2.16,>=2.15->tensorflow) (2.1.1)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /Users/nancyulloa/anaconda3/envs/dev/lib/python3.10/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /Users/nancyulloa/anaconda3/envs/dev/lib/python3.10/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow) (3.2.2)
# Using cached tensorflow-2.15.0-cp310-cp310-macosx_10_15_x86_64.whl (239.1 MB)
# Installing collected packages: tensorflow
# Successfully installed tensorflow-2.15.0

# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
import tensorflow as tf

#  Import and read the charity_data.csv.
import pandas as pd 
application_df = pd.read_csv("https://static.bc-edx.com/data/dl-1-2/m21/lms/starter/charity_data.csv")
application_df.head()
# Out:
# 2024-02-21 17:47:03.049735: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
#         EIN                                      NAME APPLICATION_TYPE  \
# 0  10520599              BLUE KNIGHTS MOTORCYCLE CLUB              T10
# 1  10531628    AMERICAN CHESAPEAKE CLUB CHARITABLE TR               T3
# 2  10547893        ST CLOUD PROFESSIONAL FIREFIGHTERS               T5
# 3  10553066            SOUTHSIDE ATHLETIC ASSOCIATION               T3
# 4  10556103  GENETIC RESEARCH INSTITUTE OF THE DESERT               T3
#
#         AFFILIATION CLASSIFICATION      USE_CASE  ORGANIZATION  STATUS  \
# 0       Independent          C1000    ProductDev   Association       1
# 1       Independent          C2000  Preservation  Co-operative       1
# 2  CompanySponsored          C3000    ProductDev   Association       1
# 3  CompanySponsored          C2000  Preservation         Trust       1
# 4       Independent          C1000     Heathcare         Trust       1
#
#       INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  IS_SUCCESSFUL
# 0              0                      N     5000              1
# 1         1-9999                      N   108590              1
# 2              0                      N     5000              0
# 3    10000-24999                      N     6692              1
# 4  100000-499999                      N   142590              1

# %%
# Drop the non-beneficial ID columns, 'EIN' and 'NAME'.
application_df = application_df.drop(columns = ['EIN', 'NAME'])

# %%
# Determine the number of unique values in each column.
application_df.nunique()
# Out:
# APPLICATION_TYPE            17
# AFFILIATION                  6
# CLASSIFICATION              71
# USE_CASE                     5
# ORGANIZATION                 4
# STATUS                       2
# INCOME_AMT                   9
# SPECIAL_CONSIDERATIONS       2
# ASK_AMT                   8747
# IS_SUCCESSFUL                2
# dtype: int64

# %%
# Look at APPLICATION_TYPE value counts for binning
app_type_counts = application_df['APPLICATION_TYPE'].value_counts()
app_type_counts
# Out:
# APPLICATION_TYPE
# T3     27037
# T4      1542
# T6      1216
# T5      1173
# T19     1065
# T8       737
# T7       725
# T10      528
# T9       156
# T13       66
# T12       27
# T2        16
# T25        3
# T14        3
# T29        2
# T15        2
# T17        1
# Name: count, dtype: int64

# %%
# Choose a cutoff value and create a list of application types to be replaced
# use the variable name `application_types_to_replace`
application_types_to_replace = list(app_type_counts[app_type_counts < 550].index)

# Replace in dataframe
for app in application_types_to_replace:
    application_df['APPLICATION_TYPE'] = application_df['APPLICATION_TYPE'].replace(app,"Other")

# Check to make sure binning was successful
application_df['APPLICATION_TYPE'].value_counts()
# Out:
# APPLICATION_TYPE
# T3       27037
# T4        1542
# T6        1216
# T5        1173
# T19       1065
# Other      804
# T8         737
# T7         725
# Name: count, dtype: int64

# %%
# Look at CLASSIFICATION value counts for binning
class_counts = application_df['CLASSIFICATION'].value_counts()
class_counts
# Out:
# CLASSIFICATION
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
#          ...
# C4120        1
# C8210        1
# C2561        1
# C4500        1
# C2150        1
# Name: count, Length: 71, dtype: int64

# %%
# You may find it helpful to look at CLASSIFICATION value counts >1
class_cleaned = class_counts.loc[class_counts > 1]
class_cleaned
# Out:
# CLASSIFICATION
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
# C7000      777
# C1700      287
# C4000      194
# C5000      116
# C1270      114
# C2700      104
# C2800       95
# C7100       75
# C1300       58
# C1280       50
# C1230       36
# C1400       34
# C7200       32
# C2300       32
# C1240       30
# C8000       20
# C7120       18
# C1500       16
# C1800       15
# C6000       15
# C1250       14
# C8200       11
# C1238       10
# C1278       10
# C1235        9
# C1237        9
# C7210        7
# C2400        6
# C1720        6
# C4100        6
# C1257        5
# C1600        5
# C1260        3
# C2710        3
# C0           3
# C3200        2
# C1234        2
# C1246        2
# C1267        2
# C1256        2
# Name: count, dtype: int64

# %%
# Choose a cutoff value and create a list of classifications to be replaced
# use the variable name `classifications_to_replace`
classifications_to_replace = list(class_counts[class_counts < 1000].index)

# Replace in dataframe
for cls in classifications_to_replace:
    application_df['CLASSIFICATION'] = application_df['CLASSIFICATION'].replace(cls,"Other")
    
# Check to make sure binning was successful
application_df['CLASSIFICATION'].value_counts()
# Out:
# CLASSIFICATION
# C1000    17326
# C2000     6074
# C1200     4837
# Other     2261
# C3000     1918
# C2100     1883
# Name: count, dtype: int64

# %%
# Convert categorical data to numeric with `pd.get_dummies`
app_dummies_df = pd.get_dummies(application_df)
app_dummies_df.head()
# Out:
#    STATUS  ASK_AMT  IS_SUCCESSFUL  APPLICATION_TYPE_Other  \
# 0       1     5000              1                    True
# 1       1   108590              1                   False
# 2       1     5000              0                   False
# 3       1     6692              1                   False
# 4       1   142590              1                   False
#
#    APPLICATION_TYPE_T19  APPLICATION_TYPE_T3  APPLICATION_TYPE_T4  \
# 0                 False                False                False
# 1                 False                 True                False
# 2                 False                False                False
# 3                 False                 True                False
# 4                 False                 True                False
#
#    APPLICATION_TYPE_T5  APPLICATION_TYPE_T6  APPLICATION_TYPE_T7  ...  \
# 0                False                False                False  ...
# 1                False                False                False  ...
# 2                 True                False                False  ...
# 3                False                False                False  ...
# 4                False                False                False  ...
#
#    INCOME_AMT_1-9999  INCOME_AMT_10000-24999  INCOME_AMT_100000-499999  \
# 0              False                   False                     False
# 1               True                   False                     False
# 2              False                   False                     False
# 3              False                    True                     False
# 4              False                   False                      True
#
#    INCOME_AMT_10M-50M  INCOME_AMT_1M-5M  INCOME_AMT_25000-99999  \
# 0               False             False                   False
# 1               False             False                   False
# 2               False             False                   False
# 3               False             False                   False
# 4               False             False                   False
#
#    INCOME_AMT_50M+  INCOME_AMT_5M-10M  SPECIAL_CONSIDERATIONS_N  \
# 0            False              False                      True
# 1            False              False                      True
# 2            False              False                      True
# 3            False              False                      True
# 4            False              False                      True
#
#    SPECIAL_CONSIDERATIONS_Y
# 0                     False
# 1                     False
# 2                     False
# 3                     False
# 4                     False
#
# [5 rows x 43 columns]

# %%
# Split our preprocessed data into our features and target arrays
y = app_dummies_df['IS_SUCCESSFUL']
X = app_dummies_df.drop(['IS_SUCCESSFUL'], axis=1)

# Split the preprocessed data into a training and testing dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=56)

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# ## Compile, Train and Evaluate the Model

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
input_features = len(X_train_scaled[0])
hidden_nodes1 = 20
hidden_nodes2 = 10

nn = tf.keras.models.Sequential()

# First hidden layer
nn.add(tf.keras.layers.Dense(units=hidden_nodes1,activation='relu',input_dim=input_features))

# Second hidden layer
nn.add(tf.keras.layers.Dense(units=hidden_nodes2,activation='relu'))

# Output layer
nn.add(tf.keras.layers.Dense(units=1, activation='sigmoid'))

# Check the structure of the model
nn.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 20)                860
#
#  dense_1 (Dense)             (None, 10)                210
#
#  dense_2 (Dense)             (None, 1)                 11
#
# =================================================================
# Total params: 1081 (4.22 KB)
# Trainable params: 1081 (4.22 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Compile the model
nn.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy'])

# %%
# Train the model
fit_model = nn.fit(X_train_scaled,y_train,epochs=100)
# Out:
# Epoch 1/100
# 804/804 [==============================] - 2s 1ms/step - loss: 0.6047 - accuracy: 0.6932
# Epoch 2/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5605 - accuracy: 0.7255
# Epoch 3/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5562 - accuracy: 0.7280
# Epoch 4/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5543 - accuracy: 0.7285
# Epoch 5/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5526 - accuracy: 0.7297
# Epoch 6/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5516 - accuracy: 0.7298
# Epoch 7/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5509 - accuracy: 0.7299
# Epoch 8/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5502 - accuracy: 0.7319
# Epoch 9/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5495 - accuracy: 0.7317
# Epoch 10/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5491 - accuracy: 0.7326
# Epoch 11/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5486 - accuracy: 0.7318
# Epoch 12/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5485 - accuracy: 0.7322
# Epoch 13/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5479 - accuracy: 0.7334
# Epoch 14/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5477 - accuracy: 0.7322
# Epoch 15/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5471 - accuracy: 0.7336
# Epoch 16/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5473 - accuracy: 0.7325
# Epoch 17/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5470 - accuracy: 0.7333
# Epoch 18/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5467 - accuracy: 0.7345
# Epoch 19/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5467 - accuracy: 0.7341
# Epoch 20/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5467 - accuracy: 0.7332
# Epoch 21/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5462 - accuracy: 0.7335
# Epoch 22/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5456 - accuracy: 0.7337
# Epoch 23/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5458 - accuracy: 0.7343
# Epoch 24/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5458 - accuracy: 0.7352
# Epoch 25/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5455 - accuracy: 0.7340
# Epoch 26/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5457 - accuracy: 0.7351
# Epoch 27/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5454 - accuracy: 0.7341
# Epoch 28/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5451 - accuracy: 0.7343
# Epoch 29/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5449 - accuracy: 0.7347
# Epoch 30/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5450 - accuracy: 0.7339
# Epoch 31/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5449 - accuracy: 0.7346
# Epoch 32/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5447 - accuracy: 0.7362
# Epoch 33/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5440 - accuracy: 0.7354
# Epoch 34/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5445 - accuracy: 0.7337
# Epoch 35/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5444 - accuracy: 0.7353
# Epoch 36/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5441 - accuracy: 0.7347
# Epoch 37/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5443 - accuracy: 0.7345
# Epoch 38/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5439 - accuracy: 0.7351
# Epoch 39/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5437 - accuracy: 0.7355
# Epoch 40/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5440 - accuracy: 0.7363
# Epoch 41/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5437 - accuracy: 0.7359
# Epoch 42/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5438 - accuracy: 0.7347
# Epoch 43/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5434 - accuracy: 0.7347
# Epoch 44/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5433 - accuracy: 0.7350
# Epoch 45/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5437 - accuracy: 0.7353
# Epoch 46/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5431 - accuracy: 0.7353
# Epoch 47/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5433 - accuracy: 0.7356
# Epoch 48/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5433 - accuracy: 0.7359
# Epoch 49/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5432 - accuracy: 0.7358
# Epoch 50/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5433 - accuracy: 0.7354
# Epoch 51/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5431 - accuracy: 0.7358
# Epoch 52/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5432 - accuracy: 0.7363
# Epoch 53/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5430 - accuracy: 0.7354
# Epoch 54/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5428 - accuracy: 0.7353
# Epoch 55/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5429 - accuracy: 0.7355
# Epoch 56/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5429 - accuracy: 0.7362
# Epoch 57/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5426 - accuracy: 0.7371
# Epoch 58/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5428 - accuracy: 0.7358
# Epoch 59/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5422 - accuracy: 0.7362
# Epoch 60/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5424 - accuracy: 0.7348
# Epoch 61/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5426 - accuracy: 0.7355
# Epoch 62/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5428 - accuracy: 0.7364
# Epoch 63/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5427 - accuracy: 0.7356
# Epoch 64/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5426 - accuracy: 0.7369
# Epoch 65/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5424 - accuracy: 0.7363
# Epoch 66/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5419 - accuracy: 0.7372
# Epoch 67/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5424 - accuracy: 0.7371
# Epoch 68/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5423 - accuracy: 0.7360
# Epoch 69/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5421 - accuracy: 0.7372
# Epoch 70/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5422 - accuracy: 0.7362
# Epoch 71/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5421 - accuracy: 0.7361
# Epoch 72/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5419 - accuracy: 0.7365
# Epoch 73/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5419 - accuracy: 0.7366
# Epoch 74/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5420 - accuracy: 0.7367
# Epoch 75/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5418 - accuracy: 0.7362
# Epoch 76/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5417 - accuracy: 0.7371
# Epoch 77/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5418 - accuracy: 0.7372
# Epoch 78/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5418 - accuracy: 0.7372
# Epoch 79/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5414 - accuracy: 0.7373
# Epoch 80/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5420 - accuracy: 0.7362
# Epoch 81/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5418 - accuracy: 0.7372
# Epoch 82/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5418 - accuracy: 0.7372
# Epoch 83/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5420 - accuracy: 0.7361
# Epoch 84/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5414 - accuracy: 0.7365
# Epoch 85/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5416 - accuracy: 0.7360
# Epoch 86/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5416 - accuracy: 0.7367
# Epoch 87/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5417 - accuracy: 0.7365
# Epoch 88/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5415 - accuracy: 0.7366
# Epoch 89/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5414 - accuracy: 0.7377
# Epoch 90/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5414 - accuracy: 0.7367
# Epoch 91/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5412 - accuracy: 0.7372
# Epoch 92/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5415 - accuracy: 0.7374
# Epoch 93/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5411 - accuracy: 0.7366
# Epoch 94/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5414 - accuracy: 0.7364
# Epoch 95/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5411 - accuracy: 0.7372
# Epoch 96/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5414 - accuracy: 0.7371
# Epoch 97/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5406 - accuracy: 0.7366
# Epoch 98/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5413 - accuracy: 0.7365
# Epoch 99/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5411 - accuracy: 0.7367
# Epoch 100/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5413 - accuracy: 0.7367

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 0s - loss: 0.5522 - accuracy: 0.7314 - 368ms/epoch - 1ms/step
# Loss: 0.5522391200065613, Accuracy: 0.7314285635948181

# %%
# Export our model to HDF5 file
nn.save('AlphabetSoupCharity.h5')
